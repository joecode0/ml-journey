# %%
import pandas as pd
data_folder = '../data/'

df = pd.read_csv(data_folder + 'house-prices/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
import sys
# For every column, print the name, type, top 3 values with their counts, and the percentage of missing values
for col in df.columns:
    nunique = df[col].nunique()
    missing = df[col].isnull().sum() / len(df)
    val_counts =  df[col].value_counts()
    if len(val_counts) > 3:
        try:
            val_counts = val_counts.iloc[:3]
        except:
            print("Error with column {}".format(col))
            print(val_counts)
            sys.exit(0)
    print("{} unique, {}% missing".format(nunique, missing))
    print(val_counts)
    print("-------------------------------------------------")
# Out:
# 1460 unique, 0.0% missing
# 1      1
# 982    1
# 980    1
# Name: Id, dtype: int64
# -------------------------------------------------
# 15 unique, 0.0% missing
# 20    536
# 60    299
# 50    144
# Name: MSSubClass, dtype: int64
# -------------------------------------------------
# 5 unique, 0.0% missing
# RL    1151
# RM     218
# FV      65
# Name: MSZoning, dtype: int64
# -------------------------------------------------
# 110 unique, 0.1773972602739726% missing
# 60.0    143
# 70.0     70
# 80.0     69
# Name: LotFrontage, dtype: int64
# -------------------------------------------------
# 1073 unique, 0.0% missing
# 7200    25
# 9600    24
# 6000    17
# Name: LotArea, dtype: int64
# -------------------------------------------------
# 2 unique, 0.0% missing
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64
# -------------------------------------------------
# 2 unique, 0.9376712328767123% missing
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
# ...
